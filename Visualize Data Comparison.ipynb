# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('C:\\Python\\income.txt',header=3)
df
# Out:
#        ภาค และจังหวัด                                         Unnamed: 1  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2     ทั่วราชอาณาจักร                                                NaN
# 3            ตอนพิเศษ                                                NaN
# 4       กรุงเทพมหานคร                                                NaN
# ..                ...                                                ...
# 84           นราธิวาส                                                NaN
# 85                NaN                                                NaN
# 86                NaN                                                NaN
# 87             ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88            Source:  The Household Socio - Economic Survey, Nationa...
#
#        2541     2543     2545     2547     2549     2550     2552     2554  \
# ...

# %%
greaterbankok = df.iloc[4:8,:] #เลือกตัดเฉพาะแถวและคอลัมน์ที่เราอยากได้โดยใช้ iloc
greaterbankok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %%
#เราจะplot เปรียบเทียบกราฟ Barchart กราฟแท่ง

# %% [markdown]
# # Barchart กราฟแท่ง

# %%
## สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพและปริมณฑณ

# %%
plt.bar([1,2,3,4],greaterbankok.iloc[:,2]) #แท่งที่1ตรงตำแหน่งที่ 1 ตำแหน่งในแนวแกน x มี  4ตัว แต่ตำแหน่งในแนวแกน Y แถวที่สองเพราะเอาปี 2541
plt.title('Barchart compareting incomes of provinces in Greater Bankok in 2451') #กราฟplot ให้ขึ้นภาษาไทยให้ได้
plt.xlabel('Provinces') #ระบุได้กราฟว่าแกน x คืออะไร
plt.ylabel('Income Bath/Month/Household') #ระบุได้กราฟว่าแกน y คืออะไร
#tick แต่ละ bar จะให้ชื่อว่าอะไร
# Out:
# Text(0, 0.5, 'Income Bath/Month/Household')

# %%
#tick แต่ละ bar จะให้ชื่อว่าอะไร
plt.bar([1,2,3,4],greaterbankok.iloc[:,2],tick_label=greaterbankok.iloc[:,-1]) #ตัวเลขแทนสมาชิกตัวสุดท้ายคือ -1
plt.title('Barchart compareting incomes of provinces in Greater Bankok in 2451')
plt.xlabel('Provinces')
plt.ylabel('Income Bath/Month/Household')
# Out:
# Text(0, 0.5, 'Income Bath/Month/Household')

# %%
#plot กราฟเทียบสองปี 2541,2558 compare different years

# %%
plt.bar([1-(0.35/2),2-(0.35/2),3-(0.35/2),4-(0.35/2)],greaterbankok.iloc[:,-2],width=0.35,tick_label=greaterbankok.iloc[:,-1],color = 'y',label = '2558',align='edge') #ขยับlabelให้ตรงเนื่องจากมันไม่ตรงตัวหนังสือใช้ align 
plt.bar([1+(0.35/2),2+(0.35/2),3+(0.35/2),4+(0.35/2)],greaterbankok.iloc[:,2],width=0.35,tick_label=greaterbankok.iloc[:,-1],color = 'r',label ='2541',align='edge')
plt.title('Barchart compareting incomes of provinces in Greater Bankok in 2451,2558')
plt.xlabel('Provinces')
plt.legend(loc=1) #แสดงสี เลื่อนตำแหน่งได้ตามต้องการ #best โลเคชั่นที่ชอบที่อยากเอาไปแปะ หาดูตำแหน่งใน barchart matplotlib
plt.ylabel('Income Bath/Month/Household')
# Out:
# Text(0, 0.5, 'Income Bath/Month/Household')

# %% [markdown]
# # Stacked Bar Graph

# %%
saledata = pd.DataFrame([{'North':20,'East':10,'West':90,'South':120},
                                            {'North':220,'East':20,'West':50,'South':90}])
saledata
# Out:
#    North  East  West  South
# 0     20    10    90    120
# 1    220    20    50     90

# %%
plt.bar([1,2],saledata.iloc[:,0],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,1],bottom=saledata.iloc[:,0],tick_label=['Company A','Company B'])  #bottom=ให้มันขึ้นไปซ้อนกลับค่าที่อยู่ข้างบน คือฐานของมัน
plt.bar([1,2],saledata.iloc[:,2],bottom=saledata.iloc[:,0]+saledata.iloc[:,1],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,3],bottom=saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2],tick_label=['Company A','Company B'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Histogram แผนภูมิความถี่

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Fixing random state for reproducibility 
np.random.seed (19680801) #seed คือจุดเริ่มต้น

# %%
np.random.randn() #randomแบบnormal
# Out:
# 1.0493043103878812

# %%
mu, sigma = 100,15 #มีนเท่ากับmu มีstandardเท่ากับซิกม่า
x = mu + sigma * np.random.randn(10000)

# %%
x #0ะมีเลขอยู่ประมาณ1หมื่น
# Out:
# array([112.99148762, 108.267019  , 125.92116686, ...,  73.28843349,
#         77.0735325 , 107.25414148])

# %%
plt.hist(x,50, density=True, facecolor='g', alpha=0.75);

# %%
#Treemap กราฟสี่เหลี่ยมใช้ในการแสดงทีมปริมาณ

# %%
import squarify

# %%
volume = [350, 220, 170, 150, 50] #ที่จำเป็นคือตัวเลขปริมาณ

# %%
squarify.plot(sizes=volume) #sizeคือขนาดของสี่เหลี่ยม

# %%
labels = ['Liquid\n volume: 350k', 'Savoury\n volume: 220k', #listของกราฟที่เก็บไว้ในtable 
          'Sugar\n volume: 170k', 'Frozen\n volume: 150k', 
          'Non-food\n volume: 50k']
color_list = ['#0f7216', '#b2790c', '#ffe9a3', #อ้างถึงสี ผสมสีตัวย่อของเลขสีต่างๆ
              '#f9d4d4', '#d35158', '#ea3033']

# %%
squarify.plot(sizes=volume, label=labels,
              color=color_list, alpha=0.7) #alpha คือความโปร่งใส

# %% [markdown]
# # Radar Chart เปรียบเทียบสองอย่าง ดูว่าอันไหนดีกว่า

# %%
import pandas as pd #ใช้กันตาราง
from math import pi #import ค่ายpi

# %%
pi
# Out:
# 3.141592653589793

# %%
df = pd.DataFrame([{'client':'c1','cheese':2,'beer':2,'chicken':5,'bread':4,'coffee':2},
                                     {'client':'c2','cheese':5,'beer':1,'chicken':3,'bread':3,'coffee':3},
                                     {'client':'c3','cheese':4,'beer':3,'chicken':3,'bread':2,'coffee':5}, 
                                     {'client':'c4','cheese':3,'beer':5,'chicken':4,'bread':1,'coffee':3}])
df
# Out:
#   client  cheese  beer  chicken  bread  coffee
# 0     c1       2     2        5      4       2
# 1     c2       5     1        3      3       3
# 2     c3       4     3        3      2       5
# 3     c4       3     5        4      1       3

# %%
# โค้ดที่ใช้ในการคำนวณว่าจะลากเส้นไปจุดไหบ้าง
#ตัดแต่ตัวหัวแถว
categories = list(df)[1:]
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True)) #ซัพพอทที่สร้างเรดาห์
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)
plt.ylim(0, 5)
ax.set_rlabel_position(30)
ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)

# %%
#เตรียม canvas กระดานวาดรูป
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)
plt.ylim(0, 5)
ax.set_rlabel_position(30)
 
# part 1 คนแรก
val_c1 = df.loc[0].drop('client').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)
 
# part 2 คนที่สอง
val_c2=df.loc[1].drop('client').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)
 
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %% [markdown]
# # Word cloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from wordcloud import WordCloud

# %%
import os
from os import path

# %%
df = pd.read_csv('C:\\Python\\message.csv')
df
# Out:
#      Unnamed: 0                       PartitionKey      RowKey  \
# 0             0  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168228
# 1             1  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168251
# 2             2  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168285
# 3             3  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168308
# 4             4  U0322c3e8de4f8a4eac8ec3bbefa21cfb  1582168312
# ..          ...                                ...         ...
# 963         963  Uf9cb1d388c137ce49307370e6e9120e1  1582631314
# 964         964  Ufd3d31906486863b4dabc0b563c7802a  1582604220
# 965         965  Ufd3d31906486863b4dabc0b563c7802a  1582604226
# 966         966  Ufd3d31906486863b4dabc0b563c7802a  1582604239
# 967         967  Ufd3d31906486863b4dabc0b563c7802a  1582604245
#
#                             Timestamp                     message  \
# 0    2020-02-20 03:10:29.464192+00:00                       Hello
# 1    2020-02-20 03:10:52.853726+00:00  img : not a parasite image
# ...

# %%
data = df.iloc[:,4]
data
# Out:
# 0                           Hello
# 1      img : not a parasite image
# 2                 img : Trichuris
# 3                   img : Ascaris
# 4                           อาการ
#                   ...
# 963                           บาย
# 964                       Dee kub
# 965                         ดีคับ
# 966                    สวัสดีครับ
# 967                            Hi
# Name: message, Length: 968, dtype: object

# %%
textdata = ' ' #สร้างลิสให้เอาฟันหนูครอบเป็น สตริง

# %%
for i in range(len(df)):
        x = df.iloc[i,4]
        textdata += x
textdata
# Out:
# ' Helloimg : not a parasite imageimg : Trichurisimg : Ascarisอาการชนิดของไข่พยาธิรู้ได้อย่างไรว่าติดพยาธิหวัดดีจ้าimg : Trichurisหวัดดีจ้าimg : hookwormsไข่พยาธิชื่อว่าอะไรไข่พยาธิชื่อว่าอะไรไข่พยาธิกลุ่มใดอาการรู้ได้อย่างไรว่าติดพยาธิimg : Trichurisimg : Trichurisimg : hookwormsลักษณะเด่นของไข่พยาธิimg : Trichurisหวัดดีจ้าาimg : not a parasite imageสวัสดีค่ะHelloจากรูปภาพเป็นไข่พยาธิชนิดใดimg : Taeniaimg : Trichurisอาการimg : OVลักษณะเด่นของไข่พยาธิไข่พยาธิชื่อว่าอะไรวิธีป้องกันHelloimg : not a parasite imageimg : Trichurisอาการimg : EnterobiusHelloimg : Taeniaimg : Ascarisimg : not a parasite imageimg : Taeniaรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิลักษณะทั่วไปตัวเต็มวัยติดต่อสู่คนได้อย่างไรตัวเต็มวัยขนาดเท่าไหร่ไข่พยาธิกลุ่มใดimg : OVรู้ได้อย่างไรว่าติดพยาธิลักษณะเด่นของไข่พยาธิimg : Trichurisดีสวัสดีimg : not a parasite imageimg : Taeniaimg : Ascarisรู้ได้อย่างไรว่าติดพยาธิอาการชนิดของไข่พยาธิimg : Trichurisimg : Ascarisimg : Trichurisชนิดของไข่พยาธิลักษณะเด่นของไข่พยาธิไข่พ
# ...

# %%
regexp = r"[ก-๙a-zA-Z']+" #กำหนดค่าตัวอย่าง

# %%
path = 'C://Python//TH-Sarabun-New//THSarabunNew.ttf' #ไปดาวน์โหลด Font ที่ต้องการใช้ ใส่ไว้ใน path ที่กำหนด

# %%
#สร้างwordcloud

# %%
# mask = np.array(Image.open("/content/mask.png")) สร้าง mask ตามรูปร่างที่ต้องการ สีดำ พื้นขาว

# %%
wordcloud = WordCloud(
                                          font_path=path, 
                                          relative_scaling = 0.3,
                                          min_font_size=1,
                                          background_color="white",
                                          width=1024,
                                          height=768,
                                          max_words=2000, 
                                          colormap='plasma', 
                                          scale=3,
                                          font_step=4,
                                          collocations=False,
                                          regexp=regexp,
                                          margin=2
                                          ).generate(textdata)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
