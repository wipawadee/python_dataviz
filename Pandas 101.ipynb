# %%
import pandas as pd

# %% [markdown]
# ## Define path to table files

# %%
w_restaurant_PATH = 'C:\\Python\\w_restaurant.csv'

# %%
search_click_PATH = 'C:\\Python\\search_click.csv'

# %% [markdown]
# ## load files into memory

# %%
w_restaurant_df = pd.read_csv(w_restaurant_PATH)
search_click_df = pd.read_csv(search_click_PATH)

# %%
w_restaurant_df
# Out:
#             id                                  name  domain_id  closed  \
# 0            2                      นครินทร์ทันตกรรม          2       0
# 1            4                          Corner House          1       0
# 2            5                        วัดโลกยสุธาราม          4       0
# 3            6                        นันท์คาราโอเกะ          1       0
# 4            7                           Buono Caffe          1       0
# ...        ...                                   ...        ...     ...
# 246842  340068                            Sushi Tama          1       0
# 246843  340070                     สะบายดี คาราโอเกะ          1       0
# 246844  340074                      สเต็กแม่&กาแฟลูก          1       0
# 246845  340079                              Mom Made          1       0
# 246846  340091  ก๋วยเตี๋ยวหมูน้ำตก ก๋วยเตี๋ยวเรือทอง          1       0
#
#                           city_name zipcode  geohash  new_open  \
# ...

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %%
search_click_df.tail()
# Out:
#         click_timestamp                             search_id  business_id  \
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# 1048570                 8     2.072630e+11  False
# 1048571                 8     6.931413e+10  False
# 1048572                 8     3.105162e+10  False
# 1048573                 8     7.848904e+10  False
# 1048574                 8     3.157757e+10  False

# %%
search_click_df.shape
# Out:
# (1048575, 6)

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ##### missing

# %%
w_restaurant_df.isnull().any()
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# ## แก้ missing

# %% [markdown]
# ## delete row with missing value ลบข้อมูลที่มี missing อยู่ออกเลย

# %%
w_restaurant_df = w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])

# %% [markdown]
#    ## fill default value to the data เติมค่า แทนค่าด้วยค่า 0

# %%
w_restaurant_df['parking'] = w_restaurant_df['parking'].fillna(0)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Select part of the table by rang by value เลือกบางส่วนของตาราง
# #### part of tanle[data_condition == True]

# %%
w_restaurant_df['parking'] >= 3
# Out:
# 61         True
# 114        True
# 115       False
# 131        True
# 140        True
#           ...
# 246722    False
# 246752     True
# 246815     True
# 246834    False
# 246842     True
# Name: parking, Length: 13669, dtype: bool

# %%
w_restaurant_df[w_restaurant_df['parking'] >= 3]
# Out:
#             id                             name  domain_id  closed  \
# 61         114                         มานีมีนม          1       0
# 114        224                     สเต็กลุงหนวด          1       0
# 131        267                              KFC          1       0
# 140        297                       Miss Mamon          1       1
# 149        344                  Inthanin Coffee          1       0
# ...        ...                              ...        ...     ...
# 246646  339670  Four Seasons Chinese Restaurant          1       0
# 246684  339718                     Jeffer Steak          1       0
# 246752  339864                         Hokkaido          1       0
# 246815  340000                     สเต็กลุงหนวด          1       0
# 246842  340068                       Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# 61      Bangkok Metropolitan Region   10312  w4rw3e0         0
# ...

# %% [markdown]
# ## HW select all restaurants from your hometown

# %%
w_restaurant_df = pd.read_csv(w_restaurant_PATH)

# %%
set(w_restaurant_df['city_name'])
# Out:
# {'Abu Dhabi',
#  'Aichi-ken',
#  'Akershus',
#  'Akita-ken',
#  'Al Farwaniyah Governorate',
#  'Alabama',
#  'Alaska',
#  'Alberta',
#  'Amnat Charoen',
#  'Andalucía',
#  'Ang Thong',
#  'Aomori-ken',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'Aragón',
#  'Argyll and Bute',
#  'Arizona',
#  'Attica',
#  'Auckland',
#  'Australia',
#  'Auvergne-Rhône-Alpes',
#  'Aydın',
#  'Ba Ria - Vung Tau',
#  'Baden-Wurttemberg',
#  'Bago Region',
#  'Bahia',
#  'Bali',
#  'Balochistan',
#  'Bangkok Metropolitan Region',
#  'Banteay Meanchey Province',
#  'Banten',
#  'Basel-Stadt',
#  'Basilicata',
#  'Basrah',
#  'Battambang',
#  'Bay Of Plenty',
#  'Bayern',
#  'Berlin',
#  'Bern',
#  'Bihar',
#  'Binh Thuan',
#  'Binh Thuan province',
#  'Borno',
#  'Bratislava',
#  'Bremen',
#  'Bretagne',
#  'British Columbia',
#  'Brussels Hoofdstedelijk Gewest',
#  'Buckinghamshire',
#  'Budapest',
#  'Bueng Kan',
#  'Buri Ram',
#  'Busan',
#  'Buskerud',
#  'C2 MALL',
#  'CALABARZON',
# ...

# %%
w_restaurant_df[w_restaurant_df['city_name'] == 'Loei']
# Out:
#             id                      name  domain_id  closed city_name zipcode  \
# 166        372  เจ๊น้อย กะเพราปลาไร้ก้าง          1       0      Loei   42120
# 203        444          The witch t cafe          1       0      Loei   42000
# 399        722                 กาแฟภูเลย          1       0      Loei   42000
# 501        870                     ณ เลย          1       0      Loei   42000
# 837       1352               บ้านต้นหลิว          1       0      Loei   42000
# ...        ...                       ...        ...     ...       ...     ...
# 245729  338647                 ส้มตำต่าย          1       0      Loei   40290
# 245773  338702                ภูผากาแฟสด          1       0      Loei   39180
# 245814  338746                 กาแฟ นมสด          1       0      Loei   42160
# 245821  338754     ก๋วยเตี๋ยว-กาแฟคุณนาย          1       0      Loei   42120
# 245908  338848              หมูยอเห็ดหอม          1       0      Loei   42110
#
# ...

# %% [markdown]
# ## save table to a file เซฟตารางลงไฟล์

# %%
w_restaurant_df.to_csv('test.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c0742761d049> in <module>
# ----> 1 w_restaurant_df.to.csv('test.csv')
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to'
